# %% [markdown]
# Pandas

# %%
pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: Error parsing dependencies of arabic-reshaper: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     fonttools (>=3.0<4.0) ; (python_version < "3") and extra == 'with-fonttools'
#               ~~~~~~^
#
# [notice] A new release of pip is available: 24.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
print("l")
# Out:
# l

# %%
data = pd.read_csv('./dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail() # data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['PassengerId']
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
type(data['PassengerId'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Series
#
# It's one dimensional array-like structurein Pandasthat can hold a sequence of value of any type. Each value in a Series is linked with a associated label called index. You can also customize the index labels in the Series

# %%
# Create  a Series from scalar value with the custom index

scalar_series = pd.Series(10, index=['a','b', 'c', 'd', 'e', 'f'])
scalar_series
# Out:
# a    10
# b    10
# c    10
# d    10
# e    10
# f    10
# dtype: int64

# %%
scalar_series['a']
# Out:
# 10

# %%
newData = [10, 20, 30, 40, 50, 60]

Data1 = pd.Series(newData, index=['a', 'b','c', 'd', 'e', 'f'])
print(Data1)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
import numpy as np
data = np.array([23,3,45,56,67,78,77])

data1 = pd.Series(data)
data1
# Out:
# 0    23
# 1     3
# 2    45
# 3    56
# 4    67
# 5    78
# 6    77
# dtype: int32

# %%
data_dict = {'a':10, 'b':23, 'c':34, 'd':56, 'e':89}

datadic = pd.Series(data_dict)
print(datadic)

datadic['a':'d'] # Slicing in Series
# Out:
# a    10
# b    23
# c    34
# d    56
# e    89
# dtype: int64
# a    10
# b    23
# c    34
# d    56
# dtype: int64

# %% [markdown]
# Functions In Series Data Structure

# %%
data = ['New Delhi', 'Washington', 'London', 'Paris']
index = ['India', 'USA', 'UK', 'France']

a = pd.Series(data, index=index)
a
# Out:
# India      New Delhi
# USA       Washington
# UK            London
# France         Paris
# dtype: object

# %%
a.index
# Out:
# Index(['India', 'USA', 'UK', 'France'], dtype='object')

# %%
a.values
# Out:
# array(['New Delhi', 'Washington', 'London', 'Paris'], dtype=object)

# %%
a.dtype
# Out:
# dtype('O')

# %%
a.shape
# Out:
# (4,)

# %%
a.size
# Out:
# 4

# %%
a.empty
# Out:
# False

# %%
a.hasnans
# Out:
# False

# %%
a.is_unique
# Out:
# True

# %%
a.ndim
# Out:
# 1

# %%
import pandas as pd
import numpy as np

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing dependencies of arabic-reshaper: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     fonttools (>=3.0<4.0) ; (python_version < "3") and extra == 'with-fonttools'
#               ~~~~~~^
#
# [notice] A new release of pip is available: 24.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = pd.read_excel('./customers.xlsx', engine='openpyxl')
data.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode
# 0   Trailsway          Road    San Diego  California   92127.0
# 1         NaN           NaN      El Paso       Texas       NaN
# 2    Arkansas        Circle  San Antonio       Texas   78220.0
# 3        Debs         Point      Memphis   Tennessee   38150.0
# 4         2nd         Drive          NaN         NaN   83732.0

# %%
# Summary if Data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   first_name     1000 non-null   object
#  2   last_name      1000 non-null   object
#  3   email          878 non-null    object
#  4   gender         957 non-null    object
#  5   street_num     738 non-null    float64
#  6   street_name    963 non-null    object
#  7   street_suffix  963 non-null    object
#  8   city           921 non-null    object
#  9   state          920 non-null    object
#  10  postcode       843 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 86.1+ KB

# %%
# I want to add new column as ' Country '  and value should be USA in the above dataframe.

data['country'] = 'USA'

data.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode country
# 0   Trailsway          Road    San Diego  California   92127.0     USA
# 1         NaN           NaN      El Paso       Texas       NaN     USA
# 2    Arkansas        Circle  San Antonio       Texas   78220.0     USA
# 3        Debs         Point      Memphis   Tennessee   38150.0     USA
# 4         2nd         Drive          NaN         NaN   83732.0     USA

# %%
# Task : I want to place Country Column after the state Column
dataa = data.drop(["country"], axis=1)

dataa.head()


dataa.insert(10, 'country', 'USA')
dataa.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state country  postcode
# 0   Trailsway          Road    San Diego  California     USA   92127.0
# 1         NaN           NaN      El Paso       Texas     USA       NaN
# 2    Arkansas        Circle  San Antonio       Texas     USA   78220.0
# 3        Debs         Point      Memphis   Tennessee     USA   38150.0
# 4         2nd         Drive          NaN         NaN     USA   83732.0

# %%
# Create a new column FullNAme  which is composed of firstname and lastname


fullName = dataa['first_name'] + ' ' + dataa['last_name']


dataa.insert(3 , 'full_name', fullName )

dataa.head()
# Out:
#    id first_name   last_name          full_name                      email  \
# 0   1     Romain   Southcott   Romain Southcott  rsouthcott0@clickbank.net
# 1   2     Cosimo   Molyneaux   Cosimo Molyneaux      cmolyneaux1@wiley.com
# 2   3      Bambi     Westrip      Bambi Westrip     bwestrip2@symantec.com
# 3   4     Roarke  Pankettman  Roarke Pankettman     rpankettman3@wiley.com
# 4   5    Mikaela    Althorpe   Mikaela Althorpe           malthorpe4@51.la
#
#    gender  street_num street_name street_suffix         city       state  \
# 0    Male         1.0   Trailsway          Road    San Diego  California
# 1    Male         NaN         NaN           NaN      El Paso       Texas
# 2  Female      4057.0    Arkansas        Circle  San Antonio       Texas
# 3    Male        74.0        Debs         Point      Memphis   Tennessee
# 4     NaN         NaN         2nd         Drive          NaN         NaN
#
#   country  postcode
# 0     USA   92127.0
# 1     USA       NaN
# ...

# %%
# loc vs iloc
   # Access the rows in given dataframe 
'''So when we create customise index and associate it to 'data_frame_demo' We can access the data/Series of that 
    particular data_frame_demo with the help loc() using customize index.     
    Also, while slicing it considers the last index in loc[]        '''

''' And if we want to access the Series/ Data using default index we use iloc(). 
    But in Iloc[] while slicing the it doesn't consider the lasst index (index-1)   '''


data_frame_demo = {
    'Name' : ['Akash', 'Amir', 'Abhishekh', 'Nehal', 'Abhijeet'],
    'Age' : [23,34,55,667,8],
    'City': ['Berlin', 'Frankfurt', 'Munich', 'Hamburg', 'Achen']
}




data_frame_demo = pd.DataFrame(data_frame_demo, index = ['A', 'B', 'C', 'D', 'E'])
data_frame_demo.head()

data_frame_demo.loc['A']
data_frame_demo.loc['B' : 'E']


# data_frame_demo_v1 = pd.DataFrame(data_frame_demo)

# data_frame_demo_v1.iloc[1]
# Out:
#         Name  Age       City
# B       Amir   34  Frankfurt
# C  Abhishekh   55     Munich
# D      Nehal  667    Hamburg
# E   Abhijeet    8      Achen

# %%
# Access the id's of of the customers from 5000 to 5004


dataa.iloc[500: 505] # This is wrong as id doesn't acts like index here it act as column ordinary

# So to get the id from 500 to 504 we have to do in this filtering way

dataa[(dataa['id'] >= 500) & (dataa['id']<= 505)]
# Out:
#       id first_name last_name         full_name                       email  \
# 499  500   Carolann   Balcock  Carolann Balcock        cbalcockdv@alexa.com
# 500  501     Elliot  Polycote   Elliot Polycote  epolycotedw@infoseek.co.jp
# 501  502   Shirline    Halpin   Shirline Halpin     shalpindx@moonfruit.com
# 502  503      Darcy  Cruddace    Darcy Cruddace                         NaN
# 503  504    Toiboid   Bentzen   Toiboid Bentzen     tbentzendz@freewebs.com
# 504  505      Paxon    Corris      Paxon Corris       pcorrise0@behance.net
#
#      gender  street_num   street_name street_suffix          city  \
# 499  Female         NaN  Stone Corner          Pass       El Paso
# 500    Male         NaN      Prentice         Drive      Hartford
# 501     NaN     76640.0         Buell        Circle        Dallas
# 502     NaN         NaN     Ridgeview         Court         Utica
# 503    Male       913.0           2nd         Trail  White Plains
# ...

# %%
# Finding the Unique Values

unique_genders = dataa['gender'].unique()
unique_genders
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
# renaming the columns in dataFrame

dataa.rename(columns={'street_num' : 'street_number' ,'street_name':'street_address'}, inplace=True)

dataa
# Out:
#        id first_name    last_name           full_name  \
# 0       1     Romain    Southcott    Romain Southcott
# 1       2     Cosimo    Molyneaux    Cosimo Molyneaux
# 2       3      Bambi      Westrip       Bambi Westrip
# 3       4     Roarke   Pankettman   Roarke Pankettman
# 4       5    Mikaela     Althorpe    Mikaela Althorpe
# ..    ...        ...          ...                 ...
# 995   996    Merrili        Alman       Merrili Alman
# 996   997    Winonah       Heckle      Winonah Heckle
# 997   998      Tobit         Birt          Tobit Birt
# 998   999     Issiah  Standbrooke  Issiah Standbrooke
# 999  1000     Elmore       Malpas       Elmore Malpas
#
#                               email  gender  street_number street_address  \
# 0         rsouthcott0@clickbank.net    Male            1.0      Trailsway
# 1             cmolyneaux1@wiley.com    Male            NaN            NaN
# 2            bwestrip2@symantec.com  Female         4057.0       Arkansas
# ...

# %%
# Count of unique values int the given columns in a dataframe

count_of_unique_values = dataa['gender'].nunique() #Returns non-null values 

count_of_unique_values
# Out:
# 2

# %%
# No of males and females

data['gender'].value_counts()
# data['country'].value_counts()/
# Out:
# Male      485
# Female    472
# Name: gender, dtype: int64

# %%
data = pd.read_excel('./purchases.xlsx', engine='openpyxl')
data
# Out:
#       Unnamed: 0    id           purch_date  customer_num  product_num  \
# 0              0     1  2019-01-03 00:00:00           823           27
# 1              1     2  2019-01-03 00:00:00           606           28
# 2              2     3  2019-01-03 00:00:00           955            9
# 3              3     4  2019-01-03 00:00:00           577           19
# 4              4     5  2019-01-03 00:00:00           429            8
# ...          ...   ...                  ...           ...          ...
# 5995        5995  5996           06/20/2019           893           33
# 5996        5996  5997           06/20/2019           566           23
# 5997        5997  5998           06/20/2019           114           19
# 5998        5998  5999           06/20/2019           404           11
# 5999        5999  6000           06/20/2019            88           57
#
#       amount     paid
# 0         12  $568.92
# 1         14  $395.36
# 2         17  $510.17
# ...

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)
data
# Out:
#         id           purch_date  customer_num  product_num  amount     paid
# 0        1  2019-01-03 00:00:00           823           27      12  $568.92
# 1        2  2019-01-03 00:00:00           606           28      14  $395.36
# 2        3  2019-01-03 00:00:00           955            9      17  $510.17
# 3        4  2019-01-03 00:00:00           577           19       3   $68.49
# 4        5  2019-01-03 00:00:00           429            8      18  $759.42
# ...    ...                  ...           ...          ...     ...      ...
# 5995  5996           06/20/2019           893           33       5  $411.10
# 5996  5997           06/20/2019           566           23      11  $178.97
# 5997  5998           06/20/2019           114           19       9  $205.47
# 5998  5999           06/20/2019           404           11      20  $429.40
# 5999  6000           06/20/2019            88           57       4  $274.52
#
# [6000 rows x 6 columns]

# %%
# Handle the datatype of columns in an appropriate manner

data['purch_date'] = pd.to_datetime(data['purch_date'])
data
# Out:
#         id purch_date  customer_num  product_num  amount     paid
# 0        1 2019-01-03           823           27      12  $568.92
# 1        2 2019-01-03           606           28      14  $395.36
# 2        3 2019-01-03           955            9      17  $510.17
# 3        4 2019-01-03           577           19       3   $68.49
# 4        5 2019-01-03           429            8      18  $759.42
# ...    ...        ...           ...          ...     ...      ...
# 5995  5996 2019-06-20           893           33       5  $411.10
# 5996  5997 2019-06-20           566           23      11  $178.97
# 5997  5998 2019-06-20           114           19       9  $205.47
# 5998  5999 2019-06-20           404           11      20  $429.40
# 5999  6000 2019-06-20            88           57       4  $274.52
#
# [6000 rows x 6 columns]

# %%
data.dtypes
# Out:
# id                       int64
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                    object
# dtype: object

# %%
# convreting the data ytpe to another data type

data['id'] = data['id'].astype(object)

print(data.dtypes)




#data['purch_date'] = data['purch_date'].astype(float) # not able to convert $ sign 
#data.dtypes



# paid -> data preprocess and then only we can do the type- conversion
'''  here we have usd regex in which the inside [] we have given \ (depicts start of expression ,$ (needs to be replaced)   by blank '' )      '''

data['paid'] = data['paid'].str.replace('[\$,]', '', regex=True).astype(float)
data.dtypes
# Out:
# id                      object
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                   float64
# dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-03746e0c536e> in <module>
#      16 '''  here we have usd regex in which the inside [] we have given \ (depicts start of expression ,$ (needs to be replaced)   by blank '' )      '''
#      17
# ---> 18 data['paid'] = data['paid'].str.replace('[\$,]', '', regex=True).astype(float)
#      19 data.dtypes
#
# c:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5135             or name in self._accessors
#    5136         ):
# -> 5137             return object.__getattribute__(self, name)
#    5138         else:
# ...

# %%
data
# Out:
#         id purch_date  customer_num  product_num  amount    paid
# 0        1 2019-01-03           823           27      12  568.92
# 1        2 2019-01-03           606           28      14  395.36
# 2        3 2019-01-03           955            9      17  510.17
# 3        4 2019-01-03           577           19       3   68.49
# 4        5 2019-01-03           429            8      18  759.42
# ...    ...        ...           ...          ...     ...     ...
# 5995  5996 2019-06-20           893           33       5  411.10
# 5996  5997 2019-06-20           566           23      11  178.97
# 5997  5998 2019-06-20           114           19       9  205.47
# 5998  5999 2019-06-20           404           11      20  429.40
# 5999  6000 2019-06-20            88           57       4  274.52
#
# [6000 rows x 6 columns]

# %% [markdown]
#        Task : Dowload the products file and perform the operations accordingly

# %%
# concate multiple dataFrames
import pandas as pd

data = pd.read_excel('./customers.xlsx', engine='openpyxl')
purchase_data = pd.read_excel('./purchases.xlsx', engine='openpyxl')
product_data = pd.read_excel('./products.xlsx', engine='openpyxl')

combined_df = pd.concat([data, purchase_data, product_data])  ## axis = 0 default row-wise concatenatiion , axis = 1 column wise concat
combined_df.head()
combined_df.drop(columns=['Unnamed: 0'])
# Out:
#     id first_name   last_name                      email  gender  street_num  \
# 0    1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1    2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2    3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3    4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4    5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
# ..  ..        ...         ...                        ...     ...         ...
# 55  56        NaN         NaN                        NaN     NaN         NaN
# 56  57        NaN         NaN                        NaN     NaN         NaN
# 57  58        NaN         NaN                        NaN     NaN         NaN
# 58  59        NaN         NaN                        NaN     NaN         NaN
# 59  60        NaN         NaN                        NaN     NaN         NaN
#
# ...

# %%
merged_data = pd.merge(data, purchase_data, on='id', how='inner')

merged_data
# Out:
#        id first_name    last_name                           email  gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net    Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3      Bambi      Westrip          bwestrip2@symantec.com  Female
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela     Althorpe                malthorpe4@51.la     NaN
# ..    ...        ...          ...                             ...     ...
# 995   996    Merrili        Alman            malmanrn@cornell.edu  Female
# 996   997    Winonah       Heckle               whecklero@fc2.com  Female
# 997   998      Tobit         Birt                             NaN    Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000     Elmore       Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# ...

# %% [markdown]
# Task : Diff. between pd.concat, pd.merge and pd.join

# %%
#Task : Diff. between pd.concat, pd.merge and pd.join

# %%
# Missing Values

data.isnull().sum()  # Count of missing values in each column
#data.isna().sum()   # Count of missing values in each column (alternative method)
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender            43
# street_num       262
# street_name       37
# street_suffix     37
# city              79
# state             80
# postcode         157
# dtype: int64

# %%
purchase_data.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# purch_date      0
# customer_num    0
# product_num     0
# amount          0
# paid            0
# dtype: int64

# %%
product_data.isnull().sum()
# Out:
# Unnamed: 0    0
# id            0
# product       0
# cost          0
# company       5
# dtype: int64

# %%
# Drop missing values
customer_data = data.copy() # not wanted to affect the original data so made a copy
customer_data

customer_data = customer_data.dropna()  # Drop rows with any missing values
customer_data.isnull().sum()
# Out:
# id               0
# first_name       0
# last_name        0
# email            0
# gender           0
# street_num       0
# street_name      0
# street_suffix    0
# city             0
# state            0
# postcode         0
# dtype: int64

# %%
customer_data.shape # from 1000 rows to 418 rows which almost 50% loss of data 

'''  
    dropna -> only when you have very small proportion of small data. Otherwise pls avoid this startegy becoz that leads to loss of data

    '''
# Out:
# '  \n    dropna -> only when you have very small proportion of small data. Otherwise pls avoid this startegy becoz that leads to loss of data\n\n    '

# %% [markdown]
# Strategy 2  : Data Imputation
#
# with measures of central tendency [mean, median, mode]

# %%
#How can we deal with categorical data

mod_gender = data['gender'].mode()[0] # replacing na/nul values with mode value of that column
mod_gender

data['gender'].fillna(mod_gender, inplace=True)
data.isna().sum()
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender             0
# street_num       262
# street_name       37
# street_suffix     37
# city              79
# state             80
# postcode         157
# dtype: int64

# %%
# How can we deal with numeric data - > ffill(), bfill(), mean(), median()
'''  ffill  (forward fill) - > 

Fill NA/NaN values by propagating the last valid observation to next valid.

Parameters:
axis{0 or ‘index’} for Series, {0 or ‘index’, 1 or ‘columns’} for DataFrame
Axis along which to fill missing values. For Series this parameter is unused and defaults to 0.

inplacebool, default False
If True, fill in-place. Note: this will modify any other views on this object (e.g., a no-copy slice for a column in a DataFrame).

limitint, default None
If method is specified, this is the maximum number of consecutive NaN values to forward/backward fill. In other words, if there is a gap with more than this number of consecutive NaNs, it will only be partially filled. If method is not specified, this is the maximum number of entries along the entire axis where NaNs will be filled. Must be greater than 0 if not None.

limit_area{None, ‘inside’, ‘outside’}, default None
If limit is specified, consecutive NaNs will be filled with this restriction.

None: No fill restriction.

‘inside’: Only fill NaNs surrounded by valid values (interpolate).

‘outside’: Only fill NaNs outside valid values (extrapolate).


       '''

data['street_num'].fillna(method='ffill', inplace=True )  
data.isnull().sum()


data['street_name'].fillna(method='ffill', inplace=True)
data.isna().sum()


data['street_suffix'].fillna(method='ffill', inplace=True)
data.isna().sum()
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender             0
# street_num         0
# street_name        0
# street_suffix      0
# city              79
# state             80
# postcode         157
# dtype: int64

# %%
'''
bfill -> 

Fill NA/NaN values by using the next valid observation to fill the gap.

Parameters:
axis{0 or ‘index’} for Series, {0 or ‘index’, 1 or ‘columns’} for DataFrame
Axis along which to fill missing values. For Series this parameter is unused and defaults to 0.

inplacebool, default False
If True, fill in-place. Note: this will modify any other views on this object (e.g., a no-copy slice for a column in a DataFrame).

limitint, default None
If method is specified, this is the maximum number of consecutive NaN values to forward/backward fill. In other words, if there is a gap with more than this number of consecutive NaNs, it will only be partially filled. If method is not specified, this is the maximum number of entries along the entire axis where NaNs will be filled. Must be greater than 0 if not None.

limit_area{None, ‘inside’, ‘outside’}, default None
If limit is specified, consecutive NaNs will be filled with this restriction.

None: No fill restriction.

‘inside’: Only fill NaNs surrounded by valid values (interpolate).

‘outside’: Only fill NaNs outside valid values (extrapolate).

'''


data['city'].fillna(method = 'bfill', inplace=True)
data['state'].fillna(method='bfill', inplace=True)
data['postcode'].fillna(method='bfill', inplace=True)

data.isnull().sum()
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender             0
# street_num         0
# street_name        0
# street_suffix      0
# city               0
# state              0
# postcode           0
# dtype: int64

# %%
data['email'].fillna('Unknown', inplace=True)
data.isna().sum()
# Out:
# id               0
# first_name       0
# last_name        0
# email            0
# gender           0
# street_num       0
# street_name      0
# street_suffix    0
# city             0
# state            0
# postcode         0
# dtype: int64

# %%
product_data['company'].fillna('unknown', inplace=True)
product_data.isna().sum()
# Out:
# Unnamed: 0    0
# id            0
# product       0
# cost          0
# company       0
# dtype: int64

# %%
purchase_data.head()
purchase_data.drop(columns=['Unnamed: 0'], inplace=True)
purchase_data['paid'] = purchase_data['paid'].str.replace('[\$,]', '', regex=True).astype(float)
purchase_data.head()

aggregated_purchase = purchase_data.groupby('customer_num').agg({'amount':'sum', 'paid':'sum'})
aggregated_purchase
# Out:
#               amount     paid
# customer_num
# 1                 24   779.34
# 2                 67  3978.09
# 3                 88  5031.39
# 4                 38  2276.38
# 5                 46  2931.24
# ...              ...      ...
# 996               31  2339.19
# 997               55  3030.34
# 998               69  3346.93
# 999               66  3640.48
# 1000              75  3961.63
#
# [997 rows x 2 columns]

# %%
# Task 
# Give me the total amount and total paid based on purchase date

aggregate_purchase_datewise = purchase_data.groupby('purch_date').agg({'amount':'sum', 'paid':'sum'})

aggregate_purchase_datewise
# Out:
#                      amount      paid
# purch_date
# 2019-01-03 00:00:00     480  20468.33
# 2019-01-04 00:00:00     872  48529.13
# 2019-01-05 00:00:00     715  38643.67
# 2019-01-06 00:00:00     576  32345.29
# 2019-02-03 00:00:00     568  28183.50
# ...                     ...       ...
# 06/16/2019              410  18338.15
# 06/17/2019              376  18200.48
# 06/18/2019              406  15061.89
# 06/19/2019              565  31095.14
# 06/20/2019              458  21474.85
#
# [108 rows x 2 columns]

# %%
data.to_excel('customers.xlsx')
purchase_data.to_excel('purchases.xlsx')
product_data.to_excel('products.xlsx')
